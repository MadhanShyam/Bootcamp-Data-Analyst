# %%
# 📚 Import necessary libraries
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %%
# Sample text data
text_data = [
    "ChatGPT is a language model developed by OpenAI.",
    "It can generate human-like responses based on text input.",
    "Text pre-processing is crucial for training language models.",
    "Feature extraction like CountVectorizer and TfidfVectorizer is essential."
]

# Convert to DataFrame for better visualization
df = pd.DataFrame({'Text': text_data})
display(df)
# Out:
#                                                 Text
# 0   ChatGPT is a language model developed by OpenAI.
# 1  It can generate human-like responses based on ...
# 2  Text pre-processing is crucial for training la...
# 3  Feature extraction like CountVectorizer and Tf...

# %%
# Initialize CountVectorizer
count_vectorizer = CountVectorizer()

# Transform text data into count vectors
count_vectors = count_vectorizer.fit_transform(text_data)

# Convert to DataFrame for better visualization
count_df = pd.DataFrame(count_vectors.toarray(), columns=count_vectorizer.get_feature_names_out())
display(count_df)

# 📌 Output: Frequency of each word in each text
]\
# Out:
#   Cell In[7], line 12
#     ]\
#     ^
# SyntaxError: unmatched ']'

# %%
# Initialize TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform text data into TF-IDF vectors
tfidf_vectors = tfidf_vectorizer.fit_transform(text_data)

# Convert to DataFrame for better visualization
tfidf_df = pd.DataFrame(tfidf_vectors.toarray(), columns=tfidf_vectorizer.get_feature_names_out())
display(tfidf_df)

# 📌 Output: TF-IDF scores indicating importance of each word in each text
# Out:
#     amazing       and     based       by       can  chatgpt  countvectorizer  \
# 0  0.000000  0.000000  0.000000  0.40933  0.000000  0.40933         0.000000
# 1  0.000000  0.000000  0.327881  0.00000  0.327881  0.00000         0.000000
# 2  0.000000  0.000000  0.000000  0.00000  0.000000  0.00000         0.000000
# 3  0.000000  0.378823  0.000000  0.00000  0.000000  0.00000         0.378823
# 4  0.369676  0.000000  0.000000  0.00000  0.000000  0.00000         0.000000
#
#    crucial  developed  essential  ...  processing  responses       run  \
# 0  0.00000    0.40933   0.000000  ...     0.00000   0.000000  0.000000
# 1  0.00000    0.00000   0.000000  ...     0.00000   0.327881  0.000000
# 2  0.36228    0.00000   0.000000  ...     0.36228   0.000000  0.000000
# 3  0.00000    0.00000   0.378823  ...     0.00000   0.000000  0.000000
# 4  0.00000    0.00000   0.000000  ...     0.00000   0.000000  0.369676
#
# ...
